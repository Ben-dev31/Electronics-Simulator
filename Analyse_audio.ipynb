# %% [markdown]
# <a href="https://colab.research.google.com/github/Ben-dev31/Electronics-Simulator/blob/master/Analyse_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install librosa==0.10.0.post2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 4.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pooch
#     Found existing installation: pooch 1.8.2
#     Uninstalling pooch-1.8.2:
#       Successfully uninstalled pooch-1.8.2
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.2.post1
#     Uninstalling librosa-0.10.2.post1:
#       Successfully uninstalled librosa-0.10.2.post1
# ...

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
audio_path = '/content/drive/MyDrive/signal/Pierre.mp3'

y, sr = librosa.load(audio_path)

# %%
plt.figure(figsize=(12, 4))
#librosa.display.waveshow(y, sr=sr)
plt.plot(y)
plt.title('Audio Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %%
ff = np.fft.fft(y)
ff_freq = np.fft.fftfreq(len(y), d=1/sr)
plt.plot(ff_freq, np.abs(ff))
plt.xlabel('Frequency')
plt.ylabel('Magnitude')
plt.title('Magnitude of Fourier Transform')
plt.grid(True)
plt.show()
